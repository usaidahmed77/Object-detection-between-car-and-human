# %%
# Object Tracking & Counting with YOLOv8 nano + Supervision + OpenCV

import cv2
import supervision as sv
from ultralytics import YOLO
import time

# Load YOLOv8 model
model = YOLO("yolov8s.pt")  # Fast lightweight model
VIDEO_PATH = "highway_car2.mp4"

# Get video info
cap = cv2.VideoCapture(VIDEO_PATH)
ret, frame = cap.read()
if not ret:
    raise ValueError("Could not read video. Check the file path.")
height, width = frame.shape[:2]
cap.release()

# Create Line Zone at middle
line_zone = sv.LineZone(
    start=sv.Point(0, height // 2),
    end=sv.Point(width, height // 2)
)
line_annotator = sv.LineZoneAnnotator()

# Bounding box annotator. This will draw bounding boxes around detected objects.
box_annotator = sv.BoxAnnotator(thickness=2)

# FPS measurement
prev_time = time.time()

# Tracking and counting loop
for result in model.track(source=VIDEO_PATH, stream=True, classes=[2], imgsz=640):
    frame = result.orig_img
    detections = sv.Detections.from_ultralytics(result)

    # Annotate bounding boxes
    frame = box_annotator.annotate(scene= frame, detections=detections)

    # Trigger line counting
    line_zone.trigger(detections)
    line_annotator.annotate(frame, line_zone)

    # Count display
    cv2.putText(frame, f"Cars In: {line_zone.in_count}", (30, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, f"Cars Out: {line_zone.out_count}", (30, 80),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # FPS calculation
    current_time = time.time()
    fps = 1 / (current_time - prev_time)
    prev_time = current_time
    cv2.putText(frame, f"FPS: {int(fps)}", (width - 150, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0), 2)

    cv2.imshow("Car Tracking & Counting", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cv2.destroyAllWindows()
# Out:
# video 1/1 (frame 1/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 473.8ms
# video 1/1 (frame 2/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 511.0ms
# video 1/1 (frame 3/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 466.0ms
# video 1/1 (frame 4/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 426.5ms
# video 1/1 (frame 5/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 436.7ms
# video 1/1 (frame 6/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 422.6ms
# video 1/1 (frame 7/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 437.2ms
# video 1/1 (frame 8/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 443.8ms
# video 1/1 (frame 9/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 429.7ms
# video 1/1 (frame 10/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 416.7ms
# video 1/1 (frame 11/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 5 cars, 420.4ms
# video 1/1 (frame 12/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 5 cars, 416.8ms
# video 1/1 (frame 13/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 5 cars, 442.9ms
# video 1/1 (frame 14/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 5 cars, 456.4ms
# video 1/1 (frame 15/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 5 cars, 415.7ms
# video 1/1 (frame 16/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 415.7ms
# video 1/1 (frame 17/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 416.7ms
# video 1/1 (frame 18/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 4 cars, 445.2ms
# video 1/1 (frame 19/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 5 cars, 421.2ms
# video 1/1 (frame 20/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 5 cars, 445.0ms
# video 1/1 (frame 21/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 5 cars, 422.3ms
# video 1/1 (frame 22/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 5 cars, 406.8ms
# video 1/1 (frame 23/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 393.0ms
# video 1/1 (frame 24/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 417.5ms
# video 1/1 (frame 25/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 438.6ms
# video 1/1 (frame 26/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 409.4ms
# video 1/1 (frame 27/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 424.4ms
# video 1/1 (frame 28/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 416.3ms
# video 1/1 (frame 29/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 413.7ms
# video 1/1 (frame 30/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 440.6ms
# video 1/1 (frame 31/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 447.7ms
# video 1/1 (frame 32/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 409.3ms
# video 1/1 (frame 33/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 6 cars, 429.4ms
# video 1/1 (frame 34/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 7 cars, 420.4ms
# video 1/1 (frame 35/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 7 cars, 436.3ms
# video 1/1 (frame 36/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 7 cars, 402.1ms
# video 1/1 (frame 37/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 7 cars, 414.5ms
# video 1/1 (frame 38/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 7 cars, 429.2ms
# video 1/1 (frame 39/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 7 cars, 422.4ms
# video 1/1 (frame 40/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 7 cars, 413.0ms
# video 1/1 (frame 41/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 7 cars, 436.1ms
# video 1/1 (frame 42/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 7 cars, 407.2ms
# video 1/1 (frame 43/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 8 cars, 430.2ms
# video 1/1 (frame 44/302) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\highway_car2.mp4: 384x640 8 cars, 412.9ms
