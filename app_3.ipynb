# %%
# Object Tracking & Counting with YOLOv8 nano + Supervision + OpenCV

import cv2
import supervision as sv
from ultralytics import YOLO
import time

# Load YOLOv8 model
model = YOLO("yolov8s.pt")  # Fast lightweight model
VIDEO_PATH = "mall_counting.mp4"

# Get video info
cap = cv2.VideoCapture(VIDEO_PATH)
ret, frame = cap.read()
if not ret:
    raise ValueError("Could not read video. Check the file path.")
height, width = frame.shape[:2]
cap.release()

# Create Line Zone at middle
line_zone = sv.LineZone(
    start=sv.Point(0, height // 2),
    end=sv.Point(width, height // 2)
)
line_annotator = sv.LineZoneAnnotator()

# Bounding box annotator. This will draw bounding boxes around detected objects.
box_annotator = sv.BoxAnnotator(thickness=2)

# FPS measurement
prev_time = time.time()

# Tracking and counting loop
for result in model.track(source=VIDEO_PATH, stream=True, classes=[0], imgsz=640):
    frame = result.orig_img
    detections = sv.Detections.from_ultralytics(result)

    # Annotate bounding boxes
    frame = box_annotator.annotate(scene= frame, detections=detections)

    # Trigger line counting
    line_zone.trigger(detections)
    line_annotator.annotate(frame, line_zone)

    # Count display
    cv2.putText(frame, f"People In: {line_zone.in_count}", (30, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, f"People Out: {line_zone.out_count}", (30, 80),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # FPS calculation
    current_time = time.time()
    fps = 1 / (current_time - prev_time)
    prev_time = current_time
    cv2.putText(frame, f"FPS: {int(fps)}", (width - 150, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0), 2)

    cv2.imshow("Car Tracking & Counting", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cv2.destroyAllWindows()
# Out:
# video 1/1 (frame 1/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 34 persons, 480.9ms
# video 1/1 (frame 2/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 34 persons, 598.4ms
# video 1/1 (frame 3/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 34 persons, 432.8ms
# video 1/1 (frame 4/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 34 persons, 434.2ms
# video 1/1 (frame 5/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 34 persons, 433.8ms
# video 1/1 (frame 6/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 34 persons, 418.5ms
# video 1/1 (frame 7/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 34 persons, 430.4ms
# video 1/1 (frame 8/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 34 persons, 431.2ms
# video 1/1 (frame 9/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 34 persons, 428.4ms
# video 1/1 (frame 10/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 426.6ms
# video 1/1 (frame 11/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 419.7ms
# video 1/1 (frame 12/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 429.9ms
# video 1/1 (frame 13/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 446.9ms
# video 1/1 (frame 14/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 704.3ms
# video 1/1 (frame 15/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 649.1ms
# video 1/1 (frame 16/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 416.2ms
# video 1/1 (frame 17/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 423.4ms
# video 1/1 (frame 18/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 408.2ms
# video 1/1 (frame 19/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 430.6ms
# video 1/1 (frame 20/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 416.5ms
# video 1/1 (frame 21/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 408.2ms
# video 1/1 (frame 22/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 424.0ms
# video 1/1 (frame 23/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 425.2ms
# video 1/1 (frame 24/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 409.0ms
# video 1/1 (frame 25/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 409.7ms
# video 1/1 (frame 26/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 408.4ms
# video 1/1 (frame 27/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 421.0ms
# video 1/1 (frame 28/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 35 persons, 420.2ms
# video 1/1 (frame 29/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 35 persons, 429.4ms
# video 1/1 (frame 30/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 429.5ms
# video 1/1 (frame 31/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 430.5ms
# video 1/1 (frame 32/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 404.5ms
# video 1/1 (frame 33/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 404.0ms
# video 1/1 (frame 34/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 420.0ms
# video 1/1 (frame 35/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 427.8ms
# video 1/1 (frame 36/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 417.8ms
# video 1/1 (frame 37/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 411.6ms
# video 1/1 (frame 38/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 400.9ms
# video 1/1 (frame 39/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 419.5ms
# video 1/1 (frame 40/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 418.4ms
# video 1/1 (frame 41/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 402.6ms
# video 1/1 (frame 42/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 38 persons, 408.6ms
# video 1/1 (frame 43/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 38 persons, 422.1ms
# video 1/1 (frame 44/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 38 persons, 429.9ms
# video 1/1 (frame 45/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 38 persons, 453.3ms
# video 1/1 (frame 46/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 501.9ms
# video 1/1 (frame 47/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 421.1ms
# video 1/1 (frame 48/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 462.3ms
# video 1/1 (frame 49/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 410.6ms
# video 1/1 (frame 50/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 415.6ms
# video 1/1 (frame 51/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 417.9ms
# video 1/1 (frame 52/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 420.4ms
# video 1/1 (frame 53/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 405.7ms
# video 1/1 (frame 54/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 422.1ms
# video 1/1 (frame 55/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 415.7ms
# video 1/1 (frame 56/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 418.9ms
# video 1/1 (frame 57/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 412.2ms
# video 1/1 (frame 58/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 419.1ms
# video 1/1 (frame 59/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 408.0ms
# video 1/1 (frame 60/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 413.1ms
# video 1/1 (frame 61/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 400.1ms
# video 1/1 (frame 62/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 409.7ms
# video 1/1 (frame 63/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 421.6ms
# video 1/1 (frame 64/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 417.3ms
# video 1/1 (frame 65/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 415.3ms
# video 1/1 (frame 66/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 36 persons, 407.4ms
# video 1/1 (frame 67/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 415.1ms
# video 1/1 (frame 68/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 37 persons, 405.5ms
# video 1/1 (frame 69/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 38 persons, 394.4ms
# video 1/1 (frame 70/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 38 persons, 403.9ms
# video 1/1 (frame 71/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 38 persons, 421.9ms
# video 1/1 (frame 72/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 38 persons, 400.4ms
# video 1/1 (frame 73/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 38 persons, 395.1ms
# video 1/1 (frame 74/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 39 persons, 412.9ms
# video 1/1 (frame 75/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 39 persons, 433.5ms
# video 1/1 (frame 76/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 40 persons, 431.9ms
# video 1/1 (frame 77/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 40 persons, 407.2ms
# video 1/1 (frame 78/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 40 persons, 634.6ms
# video 1/1 (frame 79/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 41 persons, 428.8ms
# video 1/1 (frame 80/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 41 persons, 414.8ms
# video 1/1 (frame 81/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 41 persons, 411.2ms
# video 1/1 (frame 82/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 41 persons, 413.6ms
# video 1/1 (frame 83/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 40 persons, 466.5ms
# video 1/1 (frame 84/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 40 persons, 411.4ms
# video 1/1 (frame 85/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 40 persons, 405.7ms
# video 1/1 (frame 86/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 39 persons, 417.0ms
# video 1/1 (frame 87/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 39 persons, 435.6ms
# video 1/1 (frame 88/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 39 persons, 442.1ms
# video 1/1 (frame 89/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 39 persons, 409.8ms
# video 1/1 (frame 90/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 39 persons, 610.6ms
# video 1/1 (frame 91/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 40 persons, 710.8ms
# video 1/1 (frame 92/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 40 persons, 462.0ms
# video 1/1 (frame 93/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 39 persons, 440.1ms
# video 1/1 (frame 94/341) c:\Users\NEW\Desktop\Data science\Object_Tracking_Counting\mall_counting.mp4: 384x640 38 persons, 438.8ms
